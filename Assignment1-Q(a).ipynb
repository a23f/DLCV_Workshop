# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#path of example directory
path = "/content/drive/MyDrive/Colab Notebooks/"

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

face_cascade = cv2.CascadeClassifier(cv2.samples.findFile(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml'))

img1 = cv2.imread(path+'Numb.jpg')

color_conv1 = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
faces = face_cascade.detectMultiScale(color_conv1)
for (x,y,w,h) in faces:
  cv2.rectangle(color_conv1,(x,y),(x+w,y+h),(255,0,0),2)
  face = color_conv1[y:y+h, x:x+w]
  face = cv2.GaussianBlur(face,(23, 23), 1)
  color_conv1[y:y+face.shape[0], x:x+face.shape[1]] = face
  imgCanny1 = cv2.Canny(face,15,60)
  sobelx1 = cv2.Sobel(face, cv2.CV_8U,1,0,ksize=3)
  sobely1 = cv2.Sobel(face, cv2.CV_8U,0,1,ksize=3)
  imgSobel1 = sobelx1 + sobely1

img2 = cv2.imread(path+'Smile.jpg')

color_conv2 = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)
faces = face_cascade.detectMultiScale(color_conv2)
for (x,y,w,h) in faces:
  cv2.rectangle(color_conv2,(x,y),(x+w,y+h),(255,0,0),2)
  face = color_conv2[y:y+h, x:x+w]
  face = cv2.GaussianBlur(face,(23, 23), 1)
  color_conv2[y:y+face.shape[0], x:x+face.shape[1]] = face
  imgCanny2 = cv2.Canny(face,15,60)
  sobelx2 = cv2.Sobel(face, cv2.CV_8U,1,0,ksize=3)
  sobely2 = cv2.Sobel(face, cv2.CV_8U,0,1,ksize=3)
  imgSobel2 = sobelx2 + sobely2

img3 = cv2.imread(path+'Sad.jpg')

color_conv3 = cv2.cvtColor(img3, cv2.COLOR_BGR2RGB)
faces = face_cascade.detectMultiScale(color_conv3)
for (x,y,w,h) in faces:
  cv2.rectangle(color_conv3,(x,y),(x+w,y+h),(255,0,0),2)
  face = color_conv3[y:y+h, x:x+w]
  face = cv2.GaussianBlur(face,(23, 23), 1)
  color_conv3[y:y+face.shape[0], x:x+face.shape[1]] = face
  imgCanny3 = cv2.Canny(face,15,60)
  sobelx3 = cv2.Sobel(face, cv2.CV_8U,1,0,ksize=3)
  sobely3 = cv2.Sobel(face, cv2.CV_8U,0,1,ksize=3)
  imgSobel3 = sobelx3 + sobely3

# %%
plt.figure(figsize=[10,5])
plt.subplot(121);plt.imshow(imgCanny1);plt.title("Numb Face Canny")
plt.subplot(122);plt.imshow(imgSobel1);plt.title("Numb Face Sobel")
# Out:
# Text(0.5, 1.0, 'Numb Face Sobel')

# %%
plt.figure(figsize=[10,5])
plt.subplot(121);plt.imshow(imgCanny2);plt.title("Smile Face Canny")
plt.subplot(122);plt.imshow(imgSobel2);plt.title("Smile Face Sobel")
# Out:
# Text(0.5, 1.0, 'Smile Face Sobel')

# %%
plt.figure(figsize=[10,5])
plt.subplot(121);plt.imshow(imgCanny3);plt.title("Sad Face Canny")
plt.subplot(122);plt.imshow(imgSobel3);plt.title("Sad Face Sobel")
# Out:
# Text(0.5, 1.0, 'Sad Face Sobel')
